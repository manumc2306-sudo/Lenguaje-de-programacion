# %% [markdown]
# <a href="https://colab.research.google.com/github/manumc2306-sudo/Lenguaje-de-programacion/blob/main/Clase_YahooFinance_Portafolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción a la Programación Financiera con Yahoo Finance

# %% [markdown]
# **Objetivos de la clase:**
# 1. Entender el concepto qué es un *ticker*.
# 2. Conectarse a Yahoo Finance desde Python.
# 3. Descargar datos de acciones por rango de fechas.
# 4. Trabajar con los precios de cierre.
# 5. Graficar el comportamiento y la distribución de precios.

# %% [markdown]
# ## Paso 1 – Preparar el entorno
#
# >  “Primero, vamos a instalar las herramientas que necesitaremos.”

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.0.4)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (13.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.7->yfinance) (0.1.2)

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Explicación:**
# - `yfinance`: descarga datos financieros de Yahoo Finance.
# - `pandas`: organiza los datos en tablas.
# - `matplotlib`: crea gráficos.

# %% [markdown]
# ## Paso 2 – Qué es un *ticker*
#
# >  “Cuando en finanzas hablamos de un *ticker*, nos referimos al código con el que se identifica una acción en la bolsa.”
#
# | Empresa | Ticker |
# |----------|---------|
# | Apple Inc. | AAPL |
# | Microsoft | MSFT |
# | Google (Alphabet) | GOOG |
# | Tesla | TSLA |
#
# >  *Reflexión:* así como una cédula identifica a una persona, el *ticker* identifica una acción.

# %% [markdown]
# **bold text**
# ## Paso 3 – Definir nuestro portafolio

# %%
tickers = ["AAPL", "MSFT", "GOOG","TSLA"]

# %%
type(tickers)
# Out:
# list

# %% [markdown]
# >  “Cada uno de estos *tickers* representa una empresa de nuestro portafolio.”

# %% [markdown]
# ## Paso 4 – Descargar los datos
#
# > “Vamos a descargar precios históricos de los últimos seis meses.”

# %%
data = yf.download(tickers, start="2025-05-01", end="2025-11-01") # descargamos los datos
data.head()
# Out:
# /tmp/ipython-input-3740456051.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start="2025-05-01", end="2025-11-01")
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL        GOOG        MSFT        AAPL        GOOG
# Date
# 2025-05-01  212.593048  162.449356  423.923553  213.828813  163.596959
# 2025-05-02  204.650192  165.463043  433.769287  206.284603  166.351180
# 2025-05-05  198.212219  165.702545  434.656189  203.404471  166.750351
# 2025-05-06  197.833496  164.854324  431.806122  199.966203  166.391110
# 2025-05-07  195.581207  152.480270  431.845978  198.760339  166.640580
#
# Price                          Low                                Open  \
# Ticker            MSFT        AAPL        GOOG        MSFT        AAPL
# Date
# 2025-05-01  435.473324  208.188097  160.593248  423.425289  208.367492
# 2025-05-02  437.914853  201.471061  163.317548  428.497638  205.387661
# 2025-05-05  437.974618  197.534544  164.125849  430.610252  202.407879
# 2025-05-06  436.210795  196.348584  162.788664  429.673565  197.534531
# 2025-05-07  436.599412  192.591431  149.177199  429.613731  198.491254
#
# Price                                  Volume
# Ticker            GOOG        MSFT       AAPL      GOOG      MSFT
# Date
# 2025-05-01  162.179932  429.613727   57365700  21904300  58938100
# 2025-05-02  164.609837  430.241565  101010600  16844900  30757400
# 2025-05-05  164.170753  431.367624   69018500  15309300  20136100
# 2025-05-06  163.616929  430.699989   51216500  10691900  15104200
# 2025-05-07  165.722507  432.334267   68536700  78729800  23295300

# %% [markdown]
# 📘 **Explicación:**
# - `start` y `end` definen el rango de tiempo.
# - El resultado es una tabla con las columnas `Open`, `High`, `Low`, `Close` y `Volume`.

# %% [markdown]
# ## Paso 5 – Trabajar solo con precios de cierre

# %%
close_prices = data["Close"]
close_prices.head()
# Out:
# Ticker            AAPL        GOOG        MSFT
# Date
# 2025-05-01  212.593048  162.449356  423.923553
# 2025-05-02  204.650192  165.463043  433.769287
# 2025-05-05  198.212219  165.702545  434.656189
# 2025-05-06  197.833496  164.854324  431.806122
# 2025-05-07  195.581207  152.480270  431.845978

# %% [markdown]
# >  “El precio de cierre es el más importante, porque refleja el valor final de cada jornada bursátil.”
#  Así es como vemos la evolución diaria de las tres empresas.

# %% [markdown]
# ##  Paso 6 – Visualizar la evolución de precios

# %%
close_prices.plot(figsize=(10,5))
plt.title("Evolución de precios de cierre - Portafolio tecnológico")
plt.xlabel("Fecha")
plt.ylabel("Precio (USD)")
plt.grid(True)
plt.show()

# %% [markdown]
# >  *Explicación:*
# > - Cada línea representa una empresa.
# > - Nos muestra cómo ha cambiado su valor en el tiempo.
#
#  **Preguntas:**
# - “¿Cuál de las empresas parece tener el precio más alto?”
# - “¿Observas alguna tendencia clara al alza o baja?”

# %% [markdown]
# ## 📉 Paso 7 – Analizar la distribución de precios

# %%
close_prices.hist(figsize=(10,5), bins=20)
plt.suptitle("Distribución de precios de cierre - Portafolio")
plt.show()

# %% [markdown]
# > “Este gráfico nos muestra cuántas veces los precios se concentraron en ciertos valores.”
#
#  *Interpretación:*
# - Una distribución muy extendida indica alta **volatilidad**.
# - Una distribución más compacta indica **estabilidad**.

# %% [markdown]
# ## Paso 8 – Conclusiones del análisis
#
# > “Con esto ya hicimos un primer análisis de portafolio.”
#
# Analisemos:
# - ¿Cuál empresa tuvo precios más estables?
# - ¿Cuál tuvo una tendencia creciente?
# - ¿Qué podríamos hacer si quisiéramos calcular la rentabilidad del portafolio?

# %% [markdown]
# ## Desafío práctico
#
# >  “Ahora personaliza tu propio portafolio.”
#
# **Tarea:**
# 1. Escoge tres empresas diferentes (pueden ser colombianas o internacionales).
# 2. Cambia el rango de fechas.
# 3. Genera las gráficas y explica brevemente los resultados.

# %% [markdown]
# ##  Conceptos clave aprendidos
#
# | Concepto | Significado |
# |-----------|-------------|
# | **Ticker** | Código que identifica una acción en la bolsa. |
# | **Yahoo Finance** | Plataforma con datos financieros gratuitos. |
# | **Precio de cierre (Close)** | Valor final de una acción en la jornada bursátil. |
# | **Histograma** | Representa la frecuencia de los precios. |
# | **Volatilidad** | Mide qué tanto varía el precio de una acción. |
